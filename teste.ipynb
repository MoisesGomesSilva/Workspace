# %%
import pandas as pd

# %%
teste = pd.read_csv("estoque.csv", sep= ',')
teste
# Out:
#        id_produto    loja        data  quantidade_estoque
# 0              30  Loja 6  2024-09-22                  95
# 1              18  Loja 2  2024-10-20                 172
# 2              46  Loja 3  2024-12-09                 213
# 3              20  Loja 4  2024-11-26                  91
# 4               9  Loja 4  2024-11-15                 184
# ...           ...     ...         ...                 ...
# 43915          41  Loja 3  2024-11-04                 142
# 43916          24  Loja 5  2024-11-27                 390
# 43917          41  Loja 5  2024-10-15                 204
# 43918          21  Loja 3  2024-10-31                 115
# 43919          36  Loja 3  2024-09-23                 237
#
# [43920 rows x 4 columns]

# %%
teste = pd.read_csv("produtos.csv", sep= ',')
teste
# Out:
#     id_produto                               nome          marca  \
# 0            1         Suco de Laranja Natural 1L        VitaBom
# 1            2         Água Mineral com Gás 500ml        VitaBom
# 2            3               Refrigerante Cola 2L      PureClean
# 3            4        Cerveja Artesanal IPA 350ml   FrescorPrime
# 4            5           Chá Verde Zero Açúcar 1L   FrescorPrime
# 5            6              Leite Integral UHT 1L   FrescorPrime
# 6            7      Queijo Mussarela Fatiado 200g        VitaBom
# 7            8     Iogurte Natural Desnatado 400g  GoldenHarvest
# 8            9              Manteiga com Sal 500g        VitaBom
# 9           10             Requeijão Cremoso 250g  GoldenHarvest
# 10          11             Filé Mignon Bovino 1kg    NaturezaSua
# 11          12     Peito de Frango Resfriado 800g        VitaBom
# 12          13     Linguiça Toscana Defumada 500g        VitaBom
# ...

# %%
teste = pd.read_csv("vendas.csv", sep = ",")
teste
# Out:
#         id_venda    loja            data_hora  id_produto  quantidade
# 0         V98581  Loja 1  2024-10-12 13:29:00          32           5
# 1         V85192  Loja 5  2024-10-27 16:09:00          56           2
# 2        V171149  Loja 2  2024-12-29 17:29:00          15           4
# 3         V40504  Loja 4  2024-12-24 08:54:00           3           2
# 4         V83384  Loja 2  2024-11-12 09:04:00          41           3
# ...          ...     ...                  ...         ...         ...
# 1006879   V30220  Loja 2  2024-09-19 18:38:00          43           2
# 1006880   V54702  Loja 3  2024-12-15 08:41:00          20           2
# 1006881   V20708  Loja 1  2024-12-26 11:13:00          58           2
# 1006882   V57738  Loja 1  2024-09-22 09:38:00           9           1
# 1006883    V1909  Loja 1  2024-10-07 13:49:00          22           5
#
# [1006884 rows x 5 columns]
